# %%
# llm_agent.py

from sts import compute_semantic_similarity

query = "Akun anda terdeteksi bermasalah, segera login"

results = compute_semantic_similarity(query, top_k=10)
print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # llm_agent.py
# ----> 3 from sts import compute_semantic_similarity
#       5 query = "Akun anda terdeteksi bermasalah, segera login"
#       7 results = compute_semantic_similarity(query, top_k=10)
#
# ModuleNotFoundError: No module named 'sts'
